# %%
print("Class19")
# Out:
# Class19

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0.05,10,.001)
t= np.arange(-10,-0.05,.001)

y= x**2+54/x 
z=t**2+54/t 

plt.plot(x,y)
plt.plot(t,z)
# plt.plot(x,t)

# %%
t= int(input())

def solve():
    n=int(input())
    m=int(input())
    x=input()
    s=input()  
    count=0 
    while len(x)<=len(s):
        x=x*2
        count=count+1
    if s in x:
        print(count)
        return
    x=x*2
    count = count+1
    if s in x:
        print(count)
        return    
    else :
        print(-1)
for i in range (t):
    solve()
