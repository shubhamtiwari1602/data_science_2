# %%
print("class21")
# Out:
# class21

# %%
import numpy as np
import matplotlib.pyplot as plt
x= np.arange(-10,10,.001)
y = 1/(1+np.exp(-x))
plt.plot(x,y)

plt.plot(x, [-np.log(val) if val >= 0.5 else -np.log(1 - val) for val in y])
plt.show()

# %%
#  h vs 
for i in x:
    t = 1/(1+np.exp(-x))
    if t>=0.5:
        y=1
    else :
        y=0
    if y==1:
        cost = -np.log(y)
    elif y==0:
        cost = -np.log(1-y)
